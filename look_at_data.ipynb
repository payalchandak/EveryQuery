# %%
import os
import polars as pl
datadir = 'data/mimic/raw/'

# %%
df = pl.read_parquet(os.path.join(datadir, "data/train/0.parquet"))

# %%
subj = df.sample().select('subject_id').item()
print(subj, df.filter(pl.col('subject_id')==subj)['time'].is_sorted(descending=True))
# Out:
# 13766350 False

# %%
from pathlib import Path
from nested_ragged_tensors.ragged_numpy import JointNestedRaggedTensorDict, pprint_dense

# %%
f = Path("/storage2/payal/EveryQuery/data/mimic/processed/data/train/0.nrt")
J = JointNestedRaggedTensorDict(tensors_fp=f)

# %%
import os
import polars as pl
datadir = '/storage2/payal/EveryQuery/data/mimic/processed/'
df = pl.read_parquet(os.path.join(datadir,'tokenization/schemas/train/0.parquet'))
df.sample().select('time').item().is_sorted(descending=False)
# Out:
# True
